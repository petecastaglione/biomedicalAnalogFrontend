# %% [markdown]
# # Proiectare filtru Chebyshev real, tehnica Gm-C

# %% [markdown]
# <!-- ![image.png](attachment:image.png) -->
# <img src="gmCtowThomasFilter.png" alt="drawing" width="1000"/>

# %%
import sys
import numpy as np
sys.path.append(f"C:\\Users\\maurovlachus\\OneDrive - Technical University of Cluj-Napoca\\utcn\\master\\caa\\proiect\\p1_opamps\\ekvParameterExtraction\\ekvExtractionScripts")
from siUnits import *

# %%
wp1 = 45.021
Q1 = 0.9294
wp2 = 92.1721
Q2 = 4.5943

Rdeg = siString2Num("100k")
Gm1 = 1/siString2Num("100k")
print(f"Transconductance: {num2SiStringRounded(Gm1)}; Degeneration Resistance: {num2SiStringRounded(Rdeg)}")
Gm = Gm1

C2_1 = (Gm/wp1)*Q1
C1_1 = C2_1/(Q1**2)
print(f"Rezultate bicuad 1: C1_1 = {num2SiStringRounded(C1_1)}; C2_1 = {num2SiStringRounded(C2_1)}")

C2_2 = (Gm/wp2)*Q2
C1_2 = C2_2/(Q2**2)
print(f"Rezultate bicuad 1: C1_2 = {num2SiStringRounded(C1_2)}; C2_2 = {num2SiStringRounded(C2_2)}")
# Out:
# Transconductance: 10.0u; Degeneration Resistance: 100.0k
# Rezultate bicuad 1: C1_1 = 238.991n; C2_1 = 206.437n
# Rezultate bicuad 1: C1_2 = 23.615n; C2_2 = 498.448n

# %%
wp1 = 45.021
Q1 = 0.9294
wp2 = 92.1721
Q2 = 4.5943
